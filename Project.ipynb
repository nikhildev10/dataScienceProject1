# %% [markdown]
# Pandas and Numpy have been used for Data Manipulation and numerical Calculations
#
# Matplotlib and Seaborn have been used for Data visualizations.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("apple_quality.csv")

# %% [markdown]
# head() will display the top 5 observations of the dataset

# %%
df.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
df.describe().T
# Out:
#               count         mean          std       min         25%  \
# A_id         4000.0  1999.500000  1154.844867  0.000000  999.750000
# Size         4000.0    -0.503015     1.928059 -7.151703   -1.816765
# Weight       4000.0    -0.989547     1.602507 -7.149848   -2.011770
# Sweetness    4000.0    -0.470479     1.943441 -6.894485   -1.738425
# Crunchiness  4000.0     0.985478     1.402757 -6.055058    0.062764
# Juiciness    4000.0     0.512118     1.930286 -5.961897   -0.801286
# Ripeness     4000.0     0.498277     1.874427 -5.864599   -0.771677
#
#                      50%          75%          max
# A_id         1999.500000  2999.250000  3999.000000
# Size           -0.513703     0.805526     6.406367
# Weight         -0.984736     0.030976     5.790714
# Sweetness      -0.504758     0.801922     6.374916
# Crunchiness     0.998249     1.894234     7.619852
# Juiciness       0.534219     1.835976     7.364403
# Ripeness        0.503445     1.766212     7.237837

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4001 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %% [markdown]
# isnull() is widely been in all pre-processing steps to identify null values in the data

# %%
df.isnull().sum()
# Out:
# A_id           1
# Size           1
# Weight         1
# Sweetness      1
# Crunchiness    1
# Juiciness      1
# Ripeness       1
# Acidity        0
# Quality        1
# dtype: int64

# %%
df=df.dropna()

# %%
df = pd.get_dummies(df,columns=['Quality'],dtype='int')

# %%
df.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity  Quality_bad  Quality_good
# 0  -0.491590483            0             1
# 1  -0.722809367            0             1
# 2   2.621636473            1             0
# 3   0.790723217            0             1
# 4   0.501984036            0             1

# %%
df =df.drop(columns=['A_id','Quality_bad'])
df['Quality'] = df['Quality_good']
df =df.drop(columns=['Quality_good'])

# %%
df =df.astype({'Acidity':'float64'})
df.head()
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness   Acidity  \
# 0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840 -0.491590
# 1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530 -0.722809
# 2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033  2.621636
# 3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761  0.790723
# 4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849  0.501984
#
#    Quality
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1

# %%
num_col = ['Size','Weight','Sweetness','Crunchiness','Juiciness','Ripeness','Acidity','Quality']

# %%
plt.figure(figsize=(8, 8))
sns.set(style="white")

sns.jointplot(x='Size', y='Weight', hue='Quality', data=df, palette='tab10', s=9)

# %%
plt.figure(figsize=(8, 8))
sns.set(style="white")

sns.jointplot(x='Size', y='Sweetness', hue='Quality', data=df, palette='tab10', s=9)

# %%
plt.figure(figsize=(8, 8))
sns.set(style="white")

sns.jointplot(x='Size', y='Acidity', hue='Quality', data=df, palette='tab10', s=9)

# %%
plt.figure(figsize=(8, 8))
sns.set(style="white")

sns.jointplot(x='Ripeness', y='Sweetness', hue='Quality', data=df, palette='tab10', s=9)
